# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook contains a summary of Data Science Tools & Ecosystems.

# %% [markdown]
# **Objectives:**

# %% [markdown]
# + Create a Jupyter Notebook
# + Create a Title
# + Create an Introduction
# + Create a List of Data Science Languages
# + Create a List of Data Science Libraries
# + Create a Table of Data Science Tools

# %% [markdown]
# The following list contains some of the popular languages that Data Scientists use:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. C++

# %% [markdown]
# | Data Science Tools |
# | -------------|
# | Jupyter IDE |
# | RStudio |
# | Microsoft Visual Studio |

# %% [markdown]
# ### The following are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# Below a simple arithmetic expression to multiply and then add integers:

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# The expression below will convert 200 minutes to hours by dividing by 60:

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author

# %% [markdown]
# Aubrey Haynes
